# %%
import sys
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt 
import pandas as pd
import glob 
import math
import re
from collections import defaultdict
from matplotlib.font_manager import FontProperties
import subprocess
import scipy
from scipy.stats.stats import pearsonr 
# %matplotlib inline
matplotlib.rcParams['savefig.dpi'] = 3 * matplotlib.rcParams['savefig.dpi']

# %%
# Get raw data
global outfilepath
sampleName='ddx3mut'
outfilepath=os.getcwd() + '/results/%s/'%sampleName

# %%
def modifyName(filepath,newTag):
	# Useage: Modifies the filepath name. 
	# Input: File path of format <path>/<name>.fastq and a string to add to the name.
	# Output: Returns the modified path of type <old path>_<new modifier>.fastq
    head, tail = os.path.split(filepath)
    oldname = tail.split('.')[0]
    newName = head+"/"+oldname+"_"+newTag
    return newName

def runBowtie(fastqFiles):
    # Useage: Short read mapping to reference (hg19).
    # Input: Fastq files of replicates (not paired end).
    # Output: Path to samfile for each read.
    program = 'bowtie2'
    mappedReads=[]
    unMappedReads=[]
    print "Performing Bowtie..."
    # Parameters
    # In -k mode, Bowtie 2 searches for up to N distinct, valid alignments for each read.
    # N equals the integer specified with the -k parameter. 
    # That is, if -k 2 is specified, Bowtie 2 will search for at most 2 distinct alignments
    # See http://bowtie-bio.sourceforge.net/bowtie2/manual.shtml
    for infastq in fastqFiles:

        #k='1' ;; '-k',k,
        index = os.getcwd() + '/docs/viralrepeat/retroViral'
        outfile = modifyName(infastq,"mappedToRetroviral.sam")
        unmapped = modifyName(infastq,"notMappedToRetroviral.fastq")
        
        print "Input file:"
        print infastq 
        print 'Genome index:'
        print index
        print "Output file (mapped):"
        print outfile
        print "Output file (unmapped)"
        print unmapped
        proc = subprocess.Popen([program,'-x', index,'-a','-U',infastq,'--un',unmapped,'-S',outfile,'2>>'],stdout=subprocess.PIPE,stderr=subprocess.PIPE)
        out, err = proc.communicate()
        result = out.decode()
        error = err.decode()
        print "Result : ",result 
        print "Error : ",error
        mappedReads = mappedReads + [outfile]
        unMappedReads = unMappedReads + [unmapped]
    return (mappedReads,unMappedReads)

# Run Bowtie
print "Run mapping"  
readsForRetroviralmapping=glob.glob(outfilepath+"*_notMappedTorepeat.fastq")
if readsForRetroviralmapping == []:
    readsForRetroviralmapping=glob.glob(outfilepath+"*_notMappedToRepeat.fastq") # Older file name convention
mappedReads,unmappedReads=runBowtie(readsForRetroviralmapping)
# Out:
# Run mapping
# Performing Bowtie...
# Input file:
# /arrayAhome/lmartin/CLIP/results/ddx3mut/ddx3mut_R1_3ptrimmed_filter_nodupe_5ptrimmed_notMappedToRepeat.fastq
# Genome index:
# /arrayAhome/lmartin/CLIP/docs/viralrepeat/retroViral
# Output file (mapped):
# /arrayAhome/lmartin/CLIP/results/ddx3mut/ddx3mut_R1_3ptrimmed_filter_nodupe_5ptrimmed_notMappedToRepeat_mappedToRetroviral.sam
# Output file (unmapped)
# /arrayAhome/lmartin/CLIP/results/ddx3mut/ddx3mut_R1_3ptrimmed_filter_nodupe_5ptrimmed_notMappedToRepeat_notMappedToRetroviral.fastq
# Result :
#
# Error :  Use of uninitialized value $l in scalar chomp at /seq/bowtie2-2.1.0/bowtie2 line 437, <BT> line 8969332.
# Use of uninitialized value $l in substitution (s///) at /seq/bowtie2-2.1.0/bowtie2 line 438, <BT> line 8969332.
# Use of uninitialized value $l in print at /seq/bowtie2-2.1.0/bowtie2 line 442, <BT> line 8969332.
#
# Input file:
# /arrayAhome/lmartin/CLIP/results/ddx3mut/ddx3mut_R2_3ptrimmed_filter_nodupe_5ptrimmed_notMappedToRepeat.fastq
# Genome index:
# /arrayAhome/lmartin/CLIP/docs/viralrepeat/retroViral
# Output file (mapped):
# /arrayAhome/lmartin/CLIP/results/ddx3mut/ddx3mut_R2_3ptrimmed_filter_nodupe_5ptrimmed_notMappedToRepeat_mappedToRetroviral.sam
# Output file (unmapped)
# /arrayAhome/lmartin/CLIP/results/ddx3mut/ddx3mut_R2_3ptrimmed_filter_nodupe_5ptrimmed_notMappedToRepeat_notMappedToRetroviral.fastq
# Result :
#
# Error :

# %%
def runSamtools(samfiles):
    # Useage: Samfile processing.
    # Input: Sam files from Bowtie mapping.
    # Output: Duplicate removed, sorted bedFiles.
    program = 'samtools'
    program2 = 'bamToBed'
    outBedFiles=[]
    
    for samfile in samfiles:
            
        # Convert to bamfile
        bamfile = samfile.replace('.sam', '.bam')  
        proc = subprocess.Popen( [program, 'view', '-bS', '-o', bamfile, samfile])
        proc.communicate()
        
        # Sort the bamfile and note that samtools sort adds the .bam handle
        bamfile_sort = bamfile.replace('.bam', '_sorted') 
        proc2 = subprocess.Popen( [program, 'sort', bamfile, bamfile_sort])
        proc2.communicate()
        
        # Convert to bedFile
        bedFile = bamfile_sort.replace('_sorted', '_withDupes.bed')
        outfh = open(bedFile, 'w')
        proc3 = subprocess.Popen( [program2,'-i', bamfile_sort+'.bam'],stdout=outfh)
        proc3.communicate()
        
        outBedFiles=outBedFiles+[bedFile]
        
    return outBedFiles

# Run Samtools
print "Process mapped data"  
mappedReads=glob.glob(outfilepath+"*mappedToRetroviral.sam")
mappedBedFiles=runSamtools(mappedReads)
# Out:
# Process mapped data

# %%
def makeRepeatAnnotation():
    
    # Repeat index sequence 
    repeatGenomeBuild=os.getcwd() + '/docs/viralrepeat/Hs_viralRepeat.fa'
    repeat_genome=np.genfromtxt(repeatGenomeBuild,dtype='string')
    repeat_genome_bases=repeat_genome[1]
    repeat_genome_size=len(repeat_genome[1])
    # Repeat index positions
    repeatAnnotation=os.getcwd() + '/docs/viralrepeat/Hs_viralindex_positions.txt'
    repeatAnnotDF=pd.DataFrame(pd.read_table(repeatAnnotation,header=None))
    repeatAnnotDF.columns=['Name','Length','IndexStart','IndexEnd']
    # Python list extraction is not end index inclusive; to extract sequence, use end + 1.
    repeatAnnotDF['End_for_extraction']=repeatAnnotDF['IndexEnd']+1 
    repeatAnnotDF=repeatAnnotDF.set_index('Name',drop=False)
    return (repeat_genome_bases,repeatAnnotDF)

# - Repeat annotation - 
repeat_genome_bases,repeatAnnotDF=makeRepeatAnnotation()

# %%
repeatAnnotDF
# Out:
#                                                                                   Name  \
# Name
# HERVH_ERV1_Eutheria                                                HERVH_ERV1_Eutheria
# X21_LINE_CR1_Mammalia                                            X21_LINE_CR1_Mammalia
# LTR16A_ERV3_Eutheria                                              LTR16A_ERV3_Eutheria
# LTR78_ERV1_Mammalia                                                LTR78_ERV1_Mammalia
# MARE5_hAT_Mammalia                                                  MARE5_hAT_Mammalia
# UCON50_hAT_Mammalia                                                UCON50_hAT_Mammalia
# Charlie22a_hAT_Mammalia                                        Charlie22a_hAT_Mammalia
# PrimLTR79_ERV1_Homo_sapiens                                PrimLTR79_ERV1_Homo_sapiens
# MLT1J-int_ERV3_Eutheria                                        MLT1J-int_ERV3_Eutheria
# MIR3_SINE2/tRNA_Mammalia                                      MIR3_SINE2/tRNA_Mammalia
# LTR35A_ERV1_Primates                                              LTR35A_ERV1_Primates
# X4a_DNA_DNA_transposon_Mammalia                        X4a_DNA_DNA_transposon_Mammalia
# LTR89_ERV3_Mammalia                                                LTR89_ERV3_Mammalia
# TIGGER5_Mariner/Tc1_Homo_sapiens                      TIGGER5_Mariner/Tc1_Homo_sapiens
# LTR21A_ERV1_Homo_sapiens                                      LTR21A_ERV1_Homo_sapiens
# LTR25-int_ERV1_Primates                                        LTR25-int_ERV1_Primates
# HERV18_Endogenous_Retrovirus_Homo_sapiens    HERV18_Endogenous_Retrovirus_Homo_sapiens
# MER22_MER22_Homo_sapiens                                      MER22_MER22_Homo_sapiens
# MamRep605_Transposable_Element_Mammalia        MamRep605_Transposable_Element_Mammalia
# UCON60_Repetitive_element_Mammalia                  UCON60_Repetitive_element_Mammalia
# CER_SAT_Homo_sapiens                                              CER_SAT_Homo_sapiens
# UCON55_SINE2/tRNA_Mammalia                                  UCON55_SINE2/tRNA_Mammalia
# MER21I_ERV1_Homo_sapiens                                      MER21I_ERV1_Homo_sapiens
# MER6_Mariner/Tc1_Eutheria                                    MER6_Mariner/Tc1_Eutheria
# MER57E1_ERV1_Eutheria                                            MER57E1_ERV1_Eutheria
# MER53_DNA_transposon_Homo_sapiens                    MER53_DNA_transposon_Homo_sapiens
# LTR67B_ERV3_Eutheria                                              LTR67B_ERV3_Eutheria
# UCON83_Repetitive_element_Mammalia                  UCON83_Repetitive_element_Mammalia
# LTR1F2_ERV1_Primates                                              LTR1F2_ERV1_Primates
# Tigger3c_Mariner/Tc1_Primates                            Tigger3c_Mariner/Tc1_Primates
# UCON43_Repetitive_element_Mammalia                  UCON43_Repetitive_element_Mammalia
# CHARLIE5_hAT_Homo_sapiens                                    CHARLIE5_hAT_Homo_sapiens
# LTR12_ERV1_Primates                                                LTR12_ERV1_Primates
# LTR13_ERV2_Homo_sapiens                                        LTR13_ERV2_Homo_sapiens
# X9a_DNA_DNA_transposon_Mammalia                        X9a_DNA_DNA_transposon_Mammalia
# EUTREP16_EUTREP16_Eutheria                                  EUTREP16_EUTREP16_Eutheria
# L1PA17_5_L1_Homo_sapiens                                      L1PA17_5_L1_Homo_sapiens
# MER52AI_ERV1_Homo_sapiens                                    MER52AI_ERV1_Homo_sapiens
# UCON96_Repetitive_element_Mammalia                  UCON96_Repetitive_element_Mammalia
# MamGypLTR3_Gypsy_Mammalia                                    MamGypLTR3_Gypsy_Mammalia
# HERV30I_Endogenous_Retrovirus_Homo_sapiens  HERV30I_Endogenous_Retrovirus_Homo_sapiens
# MER46C_Mariner/Tc1_Eutheria                                MER46C_Mariner/Tc1_Eutheria
# LTR14B_ERV2_Homo_sapiens                                      LTR14B_ERV2_Homo_sapiens
# MER5C_hAT_Eutheria                                                  MER5C_hAT_Eutheria
# MER58C_hAT_Eutheria                                                MER58C_hAT_Eutheria
# LTR7B_ERV3_Homo_sapiens                                        LTR7B_ERV3_Homo_sapiens
# ALR2_SAT_Homo_sapiens                                            ALR2_SAT_Homo_sapiens
# LTR42_ERV3_Homo_sapiens                                        LTR42_ERV3_Homo_sapiens
# L1PA8_L1_Homo_sapiens                                            L1PA8_L1_Homo_sapiens
# MER21B_ERV3_Eutheria                                              MER21B_ERV3_Eutheria
# L1PB4_L1_Homo_sapiens                                            L1PB4_L1_Homo_sapiens
# LTR8A_ERV1_Homo_sapiens                                        LTR8A_ERV1_Homo_sapiens
# SATR2_SAT_Homo_sapiens                                          SATR2_SAT_Homo_sapiens
# LTR6B_ERV1_Homo_sapiens                                        LTR6B_ERV1_Homo_sapiens
# MER67B_ERV1_Homo_sapiens                                      MER67B_ERV1_Homo_sapiens
# LTR64_ERV1_Homo_sapiens                                        LTR64_ERV1_Homo_sapiens
# L1MDA_5_L1_Eutheria                                                L1MDA_5_L1_Eutheria
# L1MC4B_L1_Eutheria                                                  L1MC4B_L1_Eutheria
# X13_DNA_Mariner/Tc1_Mammalia                              X13_DNA_Mariner/Tc1_Mammalia
# LTR47A2_ERV3_Homo_sapiens                                    LTR47A2_ERV3_Homo_sapiens
#                                                                                    ...
#
#                                             Length  IndexStart  IndexEnd  \
# Name
# HERVH_ERV1_Eutheria                           7713           0      7713
# X21_LINE_CR1_Mammalia                          185        7713      7898
# LTR16A_ERV3_Eutheria                           450        7898      8348
# LTR78_ERV1_Mammalia                           1304        8348      9652
# MARE5_hAT_Mammalia                             564        9652     10216
# UCON50_hAT_Mammalia                            133       10216     10349
# Charlie22a_hAT_Mammalia                        491       10349     10840
# PrimLTR79_ERV1_Homo_sapiens                    503       10840     11343
# MLT1J-int_ERV3_Eutheria                       1387       11343     12730
# MIR3_SINE2/tRNA_Mammalia                       224       12730     12954
# LTR35A_ERV1_Primates                           547       12954     13501
# X4a_DNA_DNA_transposon_Mammalia                215       13501     13716
# LTR89_ERV3_Mammalia                            879       13716     14595
# TIGGER5_Mariner/Tc1_Homo_sapiens              2302       14595     16897
# LTR21A_ERV1_Homo_sapiens                       505       16897     17402
# LTR25-int_ERV1_Primates                       7188       17402     24590
# HERV18_Endogenous_Retrovirus_Homo_sapiens     6053       24590     30643
# MER22_MER22_Homo_sapiens                      1563       30643     32206
# MamRep605_Transposable_Element_Mammalia        876       32206     33082
# UCON60_Repetitive_element_Mammalia             137       33082     33219
# CER_SAT_Homo_sapiens                           384       33219     33603
# UCON55_SINE2/tRNA_Mammalia                     170       33603     33773
# MER21I_ERV1_Homo_sapiens                      4191       33773     37964
# MER6_Mariner/Tc1_Eutheria                      865       37964     38829
# MER57E1_ERV1_Eutheria                          373       38829     39202
# MER53_DNA_transposon_Homo_sapiens              189       39202     39391
# LTR67B_ERV3_Eutheria                           620       39391     40011
# UCON83_Repetitive_element_Mammalia             102       40011     40113
# LTR1F2_ERV1_Primates                           739       40113     40852
# Tigger3c_Mariner/Tc1_Primates                  602       40852     41454
# UCON43_Repetitive_element_Mammalia             172       41454     41626
# CHARLIE5_hAT_Homo_sapiens                     2612       41626     44238
# LTR12_ERV1_Primates                            826       44238     45064
# LTR13_ERV2_Homo_sapiens                       1007       45064     46071
# X9a_DNA_DNA_transposon_Mammalia                326       46071     46397
# EUTREP16_EUTREP16_Eutheria                     139       46397     46536
# L1PA17_5_L1_Homo_sapiens                      1734       46536     48270
# MER52AI_ERV1_Homo_sapiens                     7091       48270     55361
# UCON96_Repetitive_element_Mammalia             157       55361     55518
# MamGypLTR3_Gypsy_Mammalia                      839       55518     56357
# HERV30I_Endogenous_Retrovirus_Homo_sapiens    8257       56357     64614
# MER46C_Mariner/Tc1_Eutheria                    338       64614     64952
# LTR14B_ERV2_Homo_sapiens                       608       64952     65560
# MER5C_hAT_Eutheria                             324       65560     65884
# MER58C_hAT_Eutheria                            215       65884     66099
# LTR7B_ERV3_Homo_sapiens                        464       66099     66563
# ALR2_SAT_Homo_sapiens                          179       66563     66742
# LTR42_ERV3_Homo_sapiens                        495       66742     67237
# L1PA8_L1_Homo_sapiens                          919       67237     68156
# MER21B_ERV3_Eutheria                           863       68156     69019
# L1PB4_L1_Homo_sapiens                          903       69019     69922
# LTR8A_ERV1_Homo_sapiens                        727       69922     70649
# SATR2_SAT_Homo_sapiens                         319       70649     70968
# LTR6B_ERV1_Homo_sapiens                        558       70968     71526
# MER67B_ERV1_Homo_sapiens                       661       71526     72187
# LTR64_ERV1_Homo_sapiens                        557       72187     72744
# L1MDA_5_L1_Eutheria                           3320       72744     76064
# L1MC4B_L1_Eutheria                            1522       76064     77586
# X13_DNA_Mariner/Tc1_Mammalia                   507       77586     78093
# LTR47A2_ERV3_Homo_sapiens                      432       78093     78525
#                                                ...         ...       ...
#
#                                             End_for_extraction
# Name
# HERVH_ERV1_Eutheria                                       7714
# X21_LINE_CR1_Mammalia                                     7899
# LTR16A_ERV3_Eutheria                                      8349
# LTR78_ERV1_Mammalia                                       9653
# MARE5_hAT_Mammalia                                       10217
# UCON50_hAT_Mammalia                                      10350
# Charlie22a_hAT_Mammalia                                  10841
# PrimLTR79_ERV1_Homo_sapiens                              11344
# MLT1J-int_ERV3_Eutheria                                  12731
# MIR3_SINE2/tRNA_Mammalia                                 12955
# LTR35A_ERV1_Primates                                     13502
# X4a_DNA_DNA_transposon_Mammalia                          13717
# LTR89_ERV3_Mammalia                                      14596
# TIGGER5_Mariner/Tc1_Homo_sapiens                         16898
# LTR21A_ERV1_Homo_sapiens                                 17403
# LTR25-int_ERV1_Primates                                  24591
# HERV18_Endogenous_Retrovirus_Homo_sapiens                30644
# MER22_MER22_Homo_sapiens                                 32207
# MamRep605_Transposable_Element_Mammalia                  33083
# UCON60_Repetitive_element_Mammalia                       33220
# CER_SAT_Homo_sapiens                                     33604
# UCON55_SINE2/tRNA_Mammalia                               33774
# MER21I_ERV1_Homo_sapiens                                 37965
# MER6_Mariner/Tc1_Eutheria                                38830
# MER57E1_ERV1_Eutheria                                    39203
# MER53_DNA_transposon_Homo_sapiens                        39392
# LTR67B_ERV3_Eutheria                                     40012
# UCON83_Repetitive_element_Mammalia                       40114
# LTR1F2_ERV1_Primates                                     40853
# Tigger3c_Mariner/Tc1_Primates                            41455
# UCON43_Repetitive_element_Mammalia                       41627
# CHARLIE5_hAT_Homo_sapiens                                44239
# LTR12_ERV1_Primates                                      45065
# LTR13_ERV2_Homo_sapiens                                  46072
# X9a_DNA_DNA_transposon_Mammalia                          46398
# EUTREP16_EUTREP16_Eutheria                               46537
# L1PA17_5_L1_Homo_sapiens                                 48271
# MER52AI_ERV1_Homo_sapiens                                55362
# UCON96_Repetitive_element_Mammalia                       55519
# MamGypLTR3_Gypsy_Mammalia                                56358
# HERV30I_Endogenous_Retrovirus_Homo_sapiens               64615
# MER46C_Mariner/Tc1_Eutheria                              64953
# LTR14B_ERV2_Homo_sapiens                                 65561
# MER5C_hAT_Eutheria                                       65885
# MER58C_hAT_Eutheria                                      66100
# LTR7B_ERV3_Homo_sapiens                                  66564
# ALR2_SAT_Homo_sapiens                                    66743
# LTR42_ERV3_Homo_sapiens                                  67238
# L1PA8_L1_Homo_sapiens                                    68157
# MER21B_ERV3_Eutheria                                     69020
# L1PB4_L1_Homo_sapiens                                    69923
# LTR8A_ERV1_Homo_sapiens                                  70650
# SATR2_SAT_Homo_sapiens                                   70969
# LTR6B_ERV1_Homo_sapiens                                  71527
# MER67B_ERV1_Homo_sapiens                                 72188
# LTR64_ERV1_Homo_sapiens                                  72745
# L1MDA_5_L1_Eutheria                                      76065
# L1MC4B_L1_Eutheria                                       77587
# X13_DNA_Mariner/Tc1_Mammalia                             78094
# LTR47A2_ERV3_Homo_sapiens                                78526
#                                                            ...
#
# [1043 rows x 5 columns]

# %%
# - Get mapped bedfiles - 
def readBed(path):
    bedFile = pd.read_table(path,dtype=str,header=None)
    bedFile.columns=['Index','Start','Stop','Name','QS','Strand']
    bedFile['Start']=bedFile['Start'].astype(int)
    return bedFile

mappedBed=glob.glob(outfilepath+"*mappedToRetroviral_withDupes.bed")
bedR1=readBed(mappedBed[0])
bedR2=readBed(mappedBed[1])

# %%
mappedBed
# Out:
# ['/arrayAhome/lmartin/CLIP/results/ddx3mut/ddx3mut_R1_3ptrimmed_filter_nodupe_5ptrimmed_notMappedToRepeat_mappedToRetroviral_withDupes.bed',
#  '/arrayAhome/lmartin/CLIP/results/ddx3mut/ddx3mut_R2_3ptrimmed_filter_nodupe_5ptrimmed_notMappedToRepeat_mappedToRetroviral_withDupes.bed']

# %%
# - Record gene position of RT stop - 
recordHits=pd.DataFrame()
for ix in repeatAnnotDF.index:
    end=repeatAnnotDF.loc[ix,'IndexEnd']
    repName=repeatAnnotDF.loc[ix,'Name']
    hits_r1=bedR1[(bedR1['Start']<int(repeatAnnotDF.loc[ix,'IndexEnd'])) & (bedR1['Start']>int(repeatAnnotDF.loc[ix,'IndexStart']))].shape[0]
    hits_r2=bedR2[(bedR2['Start']<int(repeatAnnotDF.loc[ix,'IndexEnd'])) & (bedR2['Start']>int(repeatAnnotDF.loc[ix,'IndexStart']))].shape[0]
    recordHits.loc[repName,'hits_r1']=hits_r1
    recordHits.loc[repName,'hits_r2']=hits_r2
recordHits['sum']=recordHits['hits_r1']+recordHits['hits_r2']
recordHits.fillna(0,inplace=True)
recordHits.sort(['sum'],inplace=True,ascending=False)

# %%
recordHits.head(5)
# Out:
#                            hits_r1  hits_r2   sum
# L1HS_L1_Homo_sapiens          4869     4425  9294
# HERV49I_ERV1_Homo_sapiens     2752     2678  5430
# L1_L1_Homo_sapiens            2661     2104  4765
# ALU_SINE1/7SL_Primates        1511     1506  3017
# L1PREC1_L1_Homo_sapiens       1628     1344  2972
#
# [5 rows x 3 columns]

# %%
# - Evaluate consistency between replicates - 
plt.subplot(2,2,1)
plt.scatter(recordHits['hits_r1']/bedR1.shape[0],recordHits['hits_r2']/bedR2.shape[0])
plt.xticks(fontsize=5)
plt.yticks(fontsize=5)
plt.xlabel('Normalized Hits / repeat RNA (Rep1)',fontsize=5)
plt.ylabel('Normalized Hits / repeat RNA (Rep2)',fontsize=5)

plt.subplot(2,2,2)
plt.scatter(np.log10(recordHits['hits_r1']),np.log10(recordHits['hits_r2']))
plt.xticks(fontsize=5)
plt.yticks(fontsize=5)
plt.xlabel('Log10 (Raw hits / repeat RNA, Rep1)',fontsize=5)
plt.ylabel('Log10 (Raw hits / repeat RNA, Rep2)',fontsize=5)

# %%
grZero=recordHits[recordHits['sum']>0]
print grZero.shape
grZero.head(15)
# Out:
# (584, 3)
#                            hits_r1  hits_r2   sum
# L1HS_L1_Homo_sapiens          4869     4425  9294
# HERV49I_ERV1_Homo_sapiens     2752     2678  5430
# L1_L1_Homo_sapiens            2661     2104  4765
# ALU_SINE1/7SL_Primates        1511     1506  3017
# L1PREC1_L1_Homo_sapiens       1628     1344  2972
# HERVKC4_ERV2_Eutheria         1427     1273  2700
# L1PA4_L1_Homo_sapiens         1143      807  1950
# L1PA3_L1_Homo_sapiens         1078      738  1816
# L1PA5_L1_Homo_sapiens         1061      746  1807
# L1PA2_L1_Homo_sapiens          948      639  1587
# L1PA6_L1_Homo_sapiens          815      622  1437
# SVA_A_SINE_Homo_sapiens        671      626  1297
# L1PA7_L1_Homo_sapiens          707      496  1203
# L1PREC2_L1_Homo_sapiens        590      496  1086
# L1PA8_L1_Homo_sapiens          605      447  1052
#
# [15 rows x 3 columns]

# %%
# - Evaluate - 
### RANK (0 to N) of REPEAT RNA FROM ABOVE LIST 
rank=0
####

repName=grZero.index[rank]
# Hits
hits_r1=bedR1[(bedR1['Start']<int(repeatAnnotDF.loc[repName,'IndexEnd'])) & (bedR1['Start']>int(repeatAnnotDF.loc[repName,'IndexStart']))]
hits_r2=bedR2[(bedR2['Start']<int(repeatAnnotDF.loc[repName,'IndexEnd'])) & (bedR2['Start']>int(repeatAnnotDF.loc[repName,'IndexStart']))]
# Histogram
binSize=1
bins=range(repeatAnnotDF.loc[repName,'IndexStart'],repeatAnnotDF.loc[repName,'IndexEnd']+2,binSize) # Make sure bins are end coordinate inclusive
histr1,bins=np.histogram(hits_r1,bins=bins)
histr2,bins=np.histogram(hits_r2,bins=bins)
width=0.7*(bins[1]-bins[0])
center=(bins[:-1] + bins[1:])/2
plt.bar(np.array(range(0,histr1.shape[0])),np.array(list(histr1)),width=1,align='center',color='blue',alpha=0.45)
plt.bar(np.array(range(0,histr1.shape[0])),np.array(list(histr2)),width=1,align='center',color='red',alpha=0.45)
plt.xlim(0,bins.shape[0])
plt.xticks(fontsize=5)
plt.yticks(fontsize=5)
plt.title('Coverage histogram for %s'%repName,fontsize=10)
plt.xlabel('RNA position',fontsize=5)
plt.ylabel('# of reads per base',fontsize=5)

# Save data
record=pd.DataFrame()
pos=range(0,bins[-1]-bins[0])
record['Base']=pos
record['R1_count']=histr1
record['R2_count']=histr2
pathToSave=outfilepath + '%s_coverage'%repName
record.to_csv(pathToSave)

# %%
float(120/8)
# Out:
# 15.0

# %%
15*8
# Out:
# 120

# %%
15*5000
# Out:
# 75000
